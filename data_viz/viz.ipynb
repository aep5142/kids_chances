# %% [markdown]
# # Visualizations Notebook
#
# The following notebook has as a purpose to show visualizations regarding the Education status at South America.

# %% [markdown]
# ### Set up of libraries

# %%
import pandas as pd
import altair as alt
import requests

# %%
from utils import filters_countries_cols

# %%
# Loading the data
data = pd.read_csv("../data/cleaned/cleaned_data.csv")
all_countries = data[data["country_code"].notna()]
avg_outcome = pd.read_csv("../data/cleaned/avg_outcome.csv")

# %%
all_countries
# Out:
#       Unnamed: 0      country country_code  year  net_enrollment  \
# 0             26  Afghanistan          AFG  1950         3.50000
# 1             27  Afghanistan          AFG  1955         4.67000
# 2             28  Afghanistan          AFG  1960         7.27000
# 3             29  Afghanistan          AFG  1965        12.92000
# 4             30  Afghanistan          AFG  1970        16.96000
# ...          ...          ...          ...   ...             ...
# 6037        9079     Zimbabwe          ZWE  2019        81.61865
# 6038        9080     Zimbabwe          ZWE  2020        83.08571
# 6039        9081     Zimbabwe          ZWE  2021        90.57390
# 6040        9082     Zimbabwe          ZWE  2022        91.82661
# 6041        9083     Zimbabwe          ZWE  2023        90.86277
#
#       gov_exp_pct_gdp  lit_rate_adult_pct  pri_comp_rate_pct  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
# ...               ...                 ...                ...
# 6037              NaN           93.227547          90.232155
# 6038              NaN                 NaN          91.866905
# 6039              NaN                 NaN          86.099625
# 6040              NaN           89.849998          86.116936
# 6041              NaN                 NaN                NaN
#
#       pupil_teacher_primary  pupil_teacher_secondary  ...  \
# 0                       NaN                      NaN  ...
# 1                       NaN                      NaN  ...
# 2                       NaN                      NaN  ...
# 3                       NaN                      NaN  ...
# 4                       NaN                      NaN  ...
# ...                     ...                      ...  ...
# 6037                    NaN                      NaN  ...
# 6038                    NaN                      NaN  ...
# 6039                    NaN                      NaN  ...
# 6040                    NaN                      NaN  ...
# 6041                    NaN                      NaN  ...
#
#       Current education expenditure, secondary (% of total expenditure in secondary public institutions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Demand for family planning satisfied by modern methods (% of married women with demand for family planning)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          75.001228
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Government expenditure on education, total (% of government expenditure)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          10.463589
# 6038                                          15.666611
# 6039                                                NaN
# 6040                                                NaN
# 6041                                          10.688962
#
#       People using at least basic drinking water services (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          63.094954
# 6038                                          62.666456
# 6039                                          62.252798
# 6040                                          62.294255
# 6041                                                NaN
#
#       Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Trained teachers in lower secondary education (% of total teachers)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
# [5272 rows x 30 columns]

# %%
avg_outcome
# Out:
#        Unnamed: 0      country country_code  year  test_scores     gdp_pc  \
# 0               0  Afghanistan          AFG  2017     355.0000  2952.9990
# 1               1  Afghanistan          AFG  2018     354.7588  2902.3920
# 2               2  Afghanistan          AFG  2020     354.7588  2769.6858
# 3               3  Afghanistan          AFG  2000          NaN  1617.8264
# 4               4  Afghanistan          AFG  2001          NaN  1454.1108
# ...           ...          ...          ...   ...          ...        ...
# 59286       59286     Zimbabwe          ZWE  1985          NaN        NaN
# 59287       59287     Zimbabwe          ZWE  1986          NaN        NaN
# 59288       59288     Zimbabwe          ZWE  1987          NaN        NaN
# 59289       59289     Zimbabwe          ZWE  1988          NaN        NaN
# 59290       59290     Zimbabwe          ZWE  1989          NaN        NaN
#
#        population wb_region
# 0      35688941.0       NaN
# 1      36743040.0       NaN
# 2      39068977.0       NaN
# 3      20130334.0       NaN
# 4      20284303.0       NaN
# ...           ...       ...
# 59286   8686815.0       NaN
# 59287   8982579.0       NaN
# 59288   9284649.0       NaN
# 59289   9583099.0       NaN
# 59290   9864797.0       NaN
#
# [59291 rows x 8 columns]

# %% [markdown]
# ### Set up for South American Countries

# %%
sa_countries = ["Argentina", "Chile", "Peru", "Colombia", "Bolivia",
                "Eduador", "Venezuela", "Paraguay", "Uruguay", "Brazil"]

# %% [markdown]
# # **First Chart: Evolution primary net enrollment since 1950 for South American countries**
#
# This dataset includes the historical evolution of enrollment of primary education
# by South American country since 1950
#
# (net enrollment: of kids of age of going to primary school, how many of them are going)

# %%
# Getting the data
cols_1 = ["country", "year", "net_enrollment"]
enrollment_sa = filters_countries_cols(all_countries, cols)

enroll_time = alt.Chart(enrollment_sa).mark_line().encode(
    x="year",
    y="net_enrollment",
    color = "country",    
)

# %% [markdown]
# # **Second Chart: Scatter Plot relating GDP per capita in 2020 with test_scores
#
# GDP per capita data is expressed in international-$ at 2021 prices.
#
# The Harmonized Learning Outcomes (HLO) database: used by organizations like the World Bank, compiles scores from tests such as TIMSS, PISA, and others to create a single, comparable score for learning outcomes.

# %%
df_3 = avg_outcome[avg_outcome["year"] == 2020]
df_3 = df_3[df_3["gdp_pc"] <= 120000]

chart_2 = alt.Chart(df_3).mark_circle().encode(
    x = alt.X("gdp_pc", scale = alt.Scale(domain = [0, 120000])),
    y = alt.Y("test_scores"))
# Out:
# alt.Chart(...)

# %% [markdown]
# # **Third Chart**: Relation of pupil-teacher primary

# %%
all_countries
# Out:
#       Unnamed: 0      country country_code  year  net_enrollment  \
# 0             26  Afghanistan          AFG  1950         3.50000
# 1             27  Afghanistan          AFG  1955         4.67000
# 2             28  Afghanistan          AFG  1960         7.27000
# 3             29  Afghanistan          AFG  1965        12.92000
# 4             30  Afghanistan          AFG  1970        16.96000
# ...          ...          ...          ...   ...             ...
# 6037        9079     Zimbabwe          ZWE  2019        81.61865
# 6038        9080     Zimbabwe          ZWE  2020        83.08571
# 6039        9081     Zimbabwe          ZWE  2021        90.57390
# 6040        9082     Zimbabwe          ZWE  2022        91.82661
# 6041        9083     Zimbabwe          ZWE  2023        90.86277
#
#       gov_exp_pct_gdp  lit_rate_adult_pct  pri_comp_rate_pct  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
# ...               ...                 ...                ...
# 6037              NaN           93.227547          90.232155
# 6038              NaN                 NaN          91.866905
# 6039              NaN                 NaN          86.099625
# 6040              NaN           89.849998          86.116936
# 6041              NaN                 NaN                NaN
#
#       pupil_teacher_primary  pupil_teacher_secondary  ...  \
# 0                       NaN                      NaN  ...
# 1                       NaN                      NaN  ...
# 2                       NaN                      NaN  ...
# 3                       NaN                      NaN  ...
# 4                       NaN                      NaN  ...
# ...                     ...                      ...  ...
# 6037                    NaN                      NaN  ...
# 6038                    NaN                      NaN  ...
# 6039                    NaN                      NaN  ...
# 6040                    NaN                      NaN  ...
# 6041                    NaN                      NaN  ...
#
#       Current education expenditure, secondary (% of total expenditure in secondary public institutions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Demand for family planning satisfied by modern methods (% of married women with demand for family planning)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          75.001228
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Government expenditure on education, total (% of government expenditure)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          10.463589
# 6038                                          15.666611
# 6039                                                NaN
# 6040                                                NaN
# 6041                                          10.688962
#
#       People using at least basic drinking water services (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                          63.094954
# 6038                                          62.666456
# 6039                                          62.252798
# 6040                                          62.294255
# 6041                                                NaN
#
#       Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Trained teachers in lower secondary education (% of total teachers)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
#       Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6037                                                NaN
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
#
# [5272 rows x 30 columns]
