# %% [markdown]
# # Set up

# %%
import pandas as pd
import requests

# %% [markdown]
# # Loading datasets

# %%
enroll = pd.read_csv("../raw/enrollment.csv")
world_education = pd.read_csv("../raw/world-education-data.csv")
various = pd.read_csv("../raw/various_indicators.csv")

# %% [markdown]
# ### Cleaning Enrollment

# %%
enroll = enroll.rename(columns={"Entity": "country",
                                "Code": "country_code",
                                "Year":"year",
                                "Combined total net enrolment rate, primary, both sexes": "net_enrollment"})
enroll.head()
# Out:
#        country country_code  year  net_enrollment
# 0  Afghanistan          AFG  1820             0.0
# 1  Afghanistan          AFG  1825             0.0
# 2  Afghanistan          AFG  1830             0.0
# 3  Afghanistan          AFG  1835             0.0
# 4  Afghanistan          AFG  1840             0.0

# %% [markdown]
# ### Cleaned world education data

# %%
world_education.head()
# Out:
#        country country_code  year  gov_exp_pct_gdp  lit_rate_adult_pct  \
# 0  Afghanistan          AFG  1999              NaN                 NaN
# 1  Afghanistan          AFG  2000              NaN                 NaN
# 2  Afghanistan          AFG  2001              NaN                 NaN
# 3  Afghanistan          AFG  2002              NaN                 NaN
# 4  Afghanistan          AFG  2003              NaN                 NaN
#
#    pri_comp_rate_pct  pupil_teacher_primary  pupil_teacher_secondary  \
# 0                NaN               33.18571                      NaN
# 1                NaN                    NaN                      NaN
# 2                NaN                    NaN                      NaN
# 3                NaN                    NaN                      NaN
# 4                NaN                    NaN                      NaN
#
#    school_enrol_primary_pct  school_enrol_secondary_pct  \
# 0                 27.298849                         NaN
# 1                 22.162991                         NaN
# 2                 22.908590                    14.47151
# 3                 75.959747                         NaN
# 4                 96.553680                    14.07805
#
#    school_enrol_tertiary_pct
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                    1.38107

# %% [markdown]
# ### Cleaning various indicators

# %%
various = various.rename(columns={"Country Name":"country",
                                  "Country Code": "country_code",
                                  "Series Name": "variable"})
various.drop("Series Code", axis=1, inplace=True)
various = various.melt(id_vars = ["country", "country_code", "variable"], var_name="year", value_name="value")
various["year"] = various["year"].str.extract(r"(\d{4})").astype(int)
various["value"] = pd.to_numeric(various["value"], errors="coerce")
final_df = various.pivot_table(
    index=["country", "country_code", "year"],
    columns="variable",
    values="value",
    aggfunc="mean"  # default; works fine now
).reset_index()
various = various.dropna(subset=["variable"])
various = various.pivot(index = ["country", "country_code", "year"], columns = "variable", values="value").reset_index()
various
# Out:
# variable      country country_code  year  \
# 0         Afghanistan          AFG  1960
# 1         Afghanistan          AFG  1961
# 2         Afghanistan          AFG  1962
# 3         Afghanistan          AFG  1963
# 4         Afghanistan          AFG  1964
# ...               ...          ...   ...
# 17220        Zimbabwe          ZWE  2020
# 17221        Zimbabwe          ZWE  2021
# 17222        Zimbabwe          ZWE  2022
# 17223        Zimbabwe          ZWE  2023
# 17224        Zimbabwe          ZWE  2024
#
# variable  Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                  30.5
# 17221                                                  30.5
# 17222                                                  30.8
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Access to electricity (% of population)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 17220                                        52.7
# 17221                                        49.0
# 17222                                        50.1
# 17223                                        62.0
# 17224                                         NaN
#
# variable  Adequacy of social insurance programs (% of total welfare of beneficiary households)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Average working hours of children, study and work, ages 7-14 (hours per week)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Children in employment, female (% of female children ages 7-14)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Children in employment, unpaid family workers (% of children in employment, ages 7-14)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Current education expenditure, primary (% of total expenditure in primary public institutions)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Current education expenditure, secondary (% of total expenditure in secondary public institutions)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Demand for family planning satisfied by modern methods (% of married women with demand for family planning)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Government expenditure on education, total (% of government expenditure)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                             15.666611
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                             10.688962
# 17224                                             16.320335
#
# variable  People using at least basic drinking water services (% of population)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                             62.666456
# 17221                                             62.252798
# 17222                                             62.294255
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Trained teachers in lower secondary education (% of total teachers)  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# variable  Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 17220                                                   NaN
# 17221                                                   NaN
# 17222                                                   NaN
# 17223                                                   NaN
# 17224                                                   NaN
#
# [17225 rows x 20 columns]

# %%
enroll_world_education = pd.merge(enroll, world_education, on=["country_code", "year"], how="left")
enroll_world_education.drop("country_y", axis=1, inplace=True)
enroll_world_education.rename(columns={"country_x":"country"}, inplace=True)

# %%
final = pd.merge(enroll_world_education, various, on=["country_code", "year"], how="left")
final = final[final["year"] >= 1950]
final.rename(columns={"country_x": "country"}, inplace=True)
final.drop("country_y", axis=1, inplace=True)

# %%
final.to_csv("cleaned_data.csv")

# %% [markdown]
# ### Cleaning avg learning outcomes

# %%
avg_outcome = pd.read_csv("https://ourworldindata.org/grapher/learning-outcomes-vs-gdp-per-capita.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# %%
new_names = {'Entity': "country",
             'Code': "country_code",
             'Year':"year",
             'harmonized_test_scores__sex_all_students':"test_scores",
       'ny_gdp_pcap_pp_kd': "gdp_pc",
       'population_historical':"population",
       'wb_region':'wb_region'}
avg_outcome.rename(columns=new_names, inplace=True)

# %%
avg_outcome.to_csv("avg_outcome.csv")
